# %% [markdown]
# <a href="https://colab.research.google.com/github/ReihanWaiswana/Struktur-Data-D---Pertemuan-1/blob/main/Praktikum_1%E2%80%93Implementasi_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arr = []

# input 10 angka
for i in range(10):
    angka = int(input("Masukkan angka: "))
    arr.append(angka)

print("Array:", arr)
print("Nilai maksimum:", max(arr))
print("Nilai minimum:", min(arr))
print("Rata-rata:", sum(arr)/len(arr))
# Out:
# Masukkan angka: 2
# Masukkan angka: 5
# Masukkan angka: 1
# Masukkan angka: 7
# Masukkan angka: 9
# Masukkan angka: 4
# Masukkan angka: 9
# Masukkan angka: 4
# Masukkan angka: 8
# Masukkan angka: 2
# Array: [2, 5, 1, 7, 9, 4, 9, 4, 8, 2]
# Nilai maksimum: 9
# Nilai minimum: 1
# Rata-rata: 5.1
