# %% [markdown]
# <a href="https://colab.research.google.com/github/ReihanWaiswana/Struktur-Data-D---Pertemuan-1/blob/main/Latihan_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Definisi list kosong untuk menyimpan angka

# %%
list = []

# %% [markdown]
# Input 10 Angka

# %%
for i in range(10):
    angka = int(input("Masukkan angka: "))
    list.append(angka)
# Out:
# Masukkan angka: 10
# Masukkan angka: 4
# Masukkan angka: 8
# Masukkan angka: 9
# Masukkan angka: 2
# Masukkan angka: 4
# Masukkan angka: 1
# Masukkan angka: 6
# Masukkan angka: 3
# Masukkan angka: 5

# %% [markdown]
# Tampilkan nilai maksimum, minimum, dan rata-rata

# %%
print("List:", list)
print("Nilai maksimum:", max(list))
print("Nilai minimum:", min(list))
print("Rata-rata:", sum(list)/len(list))
# Out:
# List: [10, 4, 8, 9, 2, 4, 1, 6, 3, 5]
# Nilai maksimum: 10
# Nilai minimum: 1
# Rata-rata: 5.2

# %% [markdown]
# Grafik batang menggunakan matplotlib

# %%
import matplotlib.pyplot as plt
plt.bar(range(len(list)), list)
plt.title("Grafik Array")
plt.xlabel("Indeks")
plt.ylabel("Nilai")
plt.show()
